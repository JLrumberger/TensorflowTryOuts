# %% [markdown]
# <a href="https://colab.research.google.com/github/JLrumberger/TensorflowTryOuts/blob/master/2_Run_Model_on_TPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deploy a Tensorflow Model on Google Cloud TPUs
# ## Transfer the model to a [tf.Estimator](https://www.tensorflow.org/guide/custom_estimators) model
#
# The easiest way to deploy a tf model on TPUs is via the tf.Estimator wrapper tf.TPUEstimator. So the first step is to port the above ResNet model to a tf.Estimator and then port it from there to a TPUEstimator model.

# %%
import numpy as np
import tensorflow as tf

def maxpool2d(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

def resblock(x, filters, is_training):
    x = tf.layers.batch_normalization(x,training=is_training)
    x = tf.nn.relu(x)
    x = tf.layers.conv2d(x,filters,(3,3),padding='same')
    x = tf.layers.batch_normalization(x,training=is_training)
    x = tf.nn.relu(x)
    x = tf.layers.conv2d(x,filters,(3,3),padding='same')
    return x

def ResNet(x,is_training):
    filters = 64
    # Reshape input to a 4D tensor 
    x = tf.reshape(x, shape=[-1, 28, 28, 1])
    x = tf.layers.conv2d(x, filters=filters, kernel_size=(3,3),padding='same')
    x += resblock(x,filters,is_training)
    x += resblock(x,filters,is_training)
    x = maxpool2d(x)
    x += resblock(x,filters,is_training)
    x += resblock(x,filters,is_training)
    x = maxpool2d(x)
    x += resblock(x,filters,is_training)
    x += resblock(x,filters,is_training)
    x = tf.reshape(x, [-1, 7*7*filters])
    x = tf.layers.dense(x,512,activation='relu')
    out = tf.layers.dense(x,10)
    return out

def model_fn(features, labels, mode):
  # Specify the model
  logits = ResNet(x = features["x"],
                  is_training=(mode == tf.estimator.ModeKeys.TRAIN))

  predictions = {
      # Generate predictions (for PREDICT and EVAL mode)
      "classes": tf.argmax(input=logits, axis=1),
      # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
      # `logging_hook`.
      "probabilities": tf.nn.softmax(logits, name="softmax_tensor")
  }

  if mode == tf.estimator.ModeKeys.PREDICT:
    return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)

  # Calculate Loss (for both TRAIN and EVAL modes)
  loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)

  # Configure the Training Op (for TRAIN mode)
  if mode == tf.estimator.ModeKeys.TRAIN:
    optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001)
    # update op for batch_norm layer
    update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
    with tf.control_dependencies(update_ops):
        train_op = optimizer.minimize(loss=loss,
            global_step=tf.train.get_global_step())
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

  # Add evaluation metrics (for EVAL mode)
  eval_metric_ops = {
      "accuracy": tf.metrics.accuracy(
          labels=labels, predictions=predictions["classes"])}
  return tf.estimator.EstimatorSpec(
      mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# Load training and eval datasets
mnist = tf.contrib.learn.datasets.load_dataset("mnist")
train_data = mnist.train.images # Returns np.array
train_labels = np.asarray(mnist.train.labels, dtype=np.int32)
eval_data = mnist.test.images # Returns np.array
eval_labels = np.asarray(mnist.test.labels, dtype=np.int32)
  
# Create the Estimator
mnist_classifier = tf.estimator.Estimator(
    model_fn=model_fn, model_dir="/tmp/mnist_convnet_model")

# Set up logging for predictions
#tensors_to_log = {"probabilities": "softmax_tensor"}
tensors_to_log = {}
logging_hook = tf.train.LoggingTensorHook(
    tensors=tensors_to_log, every_n_iter=1000)

train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": train_data},
    y=train_labels,
    batch_size=100,
    num_epochs=None,
    shuffle=True)
mnist_classifier.train(
    input_fn=train_input_fn,
    steps=2000,
    hooks=[logging_hook])
# Evaluate the model and print results
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": eval_data},
    y=eval_labels,
    num_epochs=1,
    shuffle=False)
eval_results = mnist_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)

# %% [markdown]
# ## Migrate the model to a [TPUEstimator](https://www.tensorflow.org/api_docs/python/tf/contrib/tpu/TPUEstimator)
# In order to run a TPUEstimator model on Colab TPUs, one needs to [set up a gcs bucket](https://cloud.google.com/storage/docs/creating-buckets) and authenticate with a google account to access the gcs bucket from within Colab. After that, the changes describes in
# [How to migrate a model](https://cloud.google.com/tpu/docs/tutorials/migrating-to-tpuestimator-api) need to be implemented on the estimator model.

# %%
import json
import os
import pprint
import tensorflow as tf
import time

use_tpu = True #@param {type:"boolean"}
bucket = 'gcolab' #@param {type:"string"}

assert bucket, 'Must specify an existing GCS bucket name'
print('Using bucket: {}'.format(bucket)) #gcolab

if use_tpu:
    assert 'COLAB_TPU_ADDR' in os.environ, 'Missing TPU; did you request a TPU in Notebook Settings?'

MODEL_DIR = 'gs://{}/{}'.format(bucket, time.strftime('tpuestimator/%Y-%m-%d-%H-%M-%S'))
print('Using model dir: {}'.format(MODEL_DIR))

from google.colab import auth
auth.authenticate_user()

if 'COLAB_TPU_ADDR' in os.environ:
  TF_MASTER = 'grpc://{}'.format(os.environ['COLAB_TPU_ADDR'])
  
  # Upload credentials to TPU.
  with tf.Session(TF_MASTER) as sess:    
    with open('/content/adc.json', 'r') as f:
      auth_info = json.load(f)
    tf.contrib.cloud.configure_gcs(sess, credentials=auth_info)
  # Now credentials are set for all future sessions on this TPU.
else:
  TF_MASTER=''

with tf.Session(TF_MASTER) as session:
  pprint.pprint(session.list_devices())

# %%
# Load training and eval datasets
import numpy as np
mnist = tf.contrib.learn.datasets.load_dataset("mnist")
train_data = mnist.train.images # Returns np.array
train_labels = np.asarray(mnist.train.labels, dtype=np.int32)
eval_data = mnist.test.images # Returns np.array
eval_labels = np.asarray(mnist.test.labels, dtype=np.int32)

params = {"x_train": {"x": train_data},
          "y_train": train_labels,
          "x_test" : {"x": eval_data},
          "y_test" : eval_labels,
          "iterations_per_loop": 1024, # after each loop the TPU passes back information to host CPU
          "train_batch_size":1024,
          "eval_batch_size":1024,
          "predict_batch_size":1024,
          "epochs": 80,
          "eval_steps":1024,
          "nb_MC_samples":100}
# Out:
# Extracting MNIST-data/train-images-idx3-ubyte.gz
# Extracting MNIST-data/train-labels-idx1-ubyte.gz
# Extracting MNIST-data/t10k-images-idx3-ubyte.gz
# Extracting MNIST-data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# TPUEstimator requires all input functions to work with parameters. Furthermore TPUEstimator sets the batch_sizes as a key value pair in params for TRAIN, EVAL and PREDICT mode as specified in TPUEstimator.train_batch_size, .eval_batch_size, .predict_batch_size.
#
# The below network uses MC dropout, so it is an extension of the original ResNet based on [Gal and Ghahramani, 2015](https://arxiv.org/pdf/1506.02142.pdf)

# %%
import numpy as np
import os
import tensorflow as tf

def maxpool2d(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

def resblock(x, filters, is_training):
    # dropout always true, because it's MC dropout
    x = tf.layers.batch_normalization(x,training=is_training)
    x = tf.nn.relu(x)
    x = tf.layers.dropout(x, rate=0.2, training=True)
    x = tf.layers.conv2d(x,filters,(3,3),padding='same')
    x = tf.layers.batch_normalization(x,training=is_training)
    x = tf.nn.relu(x)
    x = tf.layers.dropout(x, rate=0.2, training=True)
    x = tf.layers.conv2d(x,filters,(3,3),padding='same')
    return x

def ResNet(x,is_training):
    filters = 64
    # Reshape input to a 4D tensor 
    x = tf.reshape(x, shape=[-1, 28, 28, 1])
    x = tf.layers.conv2d(x, filters=filters, kernel_size=(3,3),padding='same')
    x += resblock(x,filters,is_training)
    x += resblock(x,filters,is_training)
    x += resblock(x,filters,is_training)
    x = maxpool2d(x)
    x += resblock(x,filters,is_training)
    x += resblock(x,filters,is_training)
    x += resblock(x,filters,is_training)
    x = maxpool2d(x)
    x += resblock(x,filters,is_training)
    x += resblock(x,filters,is_training)
    x += resblock(x,filters,is_training)
    x = tf.reshape(x, [-1, 7*7*filters])
    x = tf.layers.dropout(x, rate=0.5, training=True)
    x = tf.layers.dense(x,512,activation='relu')
    out = tf.layers.dense(x,10)
    return out
  
def model_fn(features, labels, mode, params):
  # Specify the model
  logits = ResNet(x = features["x"],
                  is_training=(mode == tf.estimator.ModeKeys.TRAIN))

  predictions = {
      # Generate predictions (for PREDICT and EVAL mode)
      "classes": tf.argmax(input=logits, axis=1),
      # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
      # `logging_hook`.
      "probabilities": tf.nn.softmax(logits, name="softmax_tensor")
  }

  if mode == tf.estimator.ModeKeys.PREDICT:
    return tf.contrib.tpu.TPUEstimatorSpec(mode=mode, predictions=predictions)

  # Calculate Loss (for both TRAIN and EVAL modes)
  loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)

  # Configure the Training Op (for TRAIN mode)
  if mode == tf.estimator.ModeKeys.TRAIN:
    learning_rate = tf.train.exponential_decay(0.001,
          #FLAGS.learning_rate,
          tf.train.get_global_step(),
          decay_steps=100000,
          decay_rate=0.96)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
    optimizer = tf.contrib.tpu.CrossShardOptimizer(optimizer)
    # update op for batch_norm layer
    update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
    with tf.control_dependencies(update_ops):
        train_op = optimizer.minimize(loss=loss,
            global_step=tf.train.get_global_step())
    return tf.contrib.tpu.TPUEstimatorSpec(mode=mode, loss=loss, train_op=train_op)

  # Add evaluation metrics (for EVAL mode)
  return tf.contrib.tpu.TPUEstimatorSpec(
      mode=mode, loss=loss, eval_metrics=(metric_fn,[labels,logits]))

  
def metric_fn(labels, logits):
    accuracy = tf.metrics.accuracy(
        labels=labels, predictions=tf.argmax(logits, axis=1))
    return {"accuracy": accuracy}

# Create model input functions
def train_input_fn(params):
  # Convert the inputs to a Dataset.
  dataset = tf.data.Dataset.from_tensor_slices((params["x_train"], params["y_train"]))
  # Shuffle, repeat, and batch the examples.
  dataset = dataset.shuffle(1000).repeat()
  dataset = dataset.batch(params["batch_size"], drop_remainder=True)
  return dataset

def eval_input_fn(params):
  # Convert the inputs to a Dataset.
  dataset = tf.data.Dataset.from_tensor_slices((params["x_test"], params["y_test"]))
  # Shuffle, repeat, and batch the examples.
  dataset = dataset.shuffle(1000).repeat()
  dataset = dataset.batch(params["batch_size"], drop_remainder=True)
  return dataset

def predict_input_fn(params):
  # generates MC dropout probabilities
  dataset = tf.data.Dataset.from_tensor_slices(params["x_test"])
  dataset = dataset.repeat(params["nb_MC_samples"])
  dataset = dataset.batch(params["batch_size"])
  return dataset
  
# Create the Estimator
tpu_cluster_resolver = tf.contrib.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])

run_config = tf.contrib.tpu.RunConfig(
    cluster=tpu_cluster_resolver,
    model_dir=MODEL_DIR, # google cloud services bucket
    session_config=tf.ConfigProto(
        allow_soft_placement=True, log_device_placement=True),
    tpu_config=tf.contrib.tpu.TPUConfig(params["iterations_per_loop"])
)

estimator = tf.contrib.tpu.TPUEstimator(
    model_fn=model_fn,
    use_tpu=True,
    train_batch_size=params["train_batch_size"],
    eval_batch_size=params["eval_batch_size"],
    predict_batch_size=params["predict_batch_size"],
    config=run_config,
    params=params
)

# Train the model

estimator.train(input_fn=train_input_fn, steps=params["epochs"]*params["train_batch_size"])

estimator.evaluate(input_fn= eval_input_fn, steps=params["eval_steps"])
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'gs://gcolab/tpuestimator/2019-01-21-17-01-07', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# log_device_placement: true
# cluster_def {
#   job {
#     name: "worker"
#     tasks {
#       value: "10.42.1.186:8470"
#     }
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f57c35c65f8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': b'grpc://10.42.1.186:8470', '_evaluation_master': b'grpc://10.42.1.186:8470', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=1024, num_shards=None, num_cores_per_replica=None, per_host_input_for_training=2, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None), '_cluster': <tensorflow.contrib.cluster_resolver.python.training.tpu_cluster_resolver.TPUClusterResolver object at 0x7f57c35c6400>}
# INFO:tensorflow:_TPUContext: eval_on_tpu True
# INFO:tensorflow:Querying Tensorflow master (b'grpc://10.42.1.186:8470') for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 5041798690729503083)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 6654656975924903177)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_GPU:0, XLA_GPU, 17179869184, 8967096139545262718)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 2281773542974564882)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 10218791745511022133)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 10136939819865132619)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 4018180947296042307)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 4730099616946979796)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 3465953355885612079)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 5996857946266967702)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 12900366021779658631)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 5935165526541239953)
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:TPU job name worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://gcolab/tpuestimator/2019-01-21-17-01-07/model.ckpt-40960
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 40960 into gs://gcolab/tpuestimator/2019-01-21-17-01-07/model.ckpt.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Installing graceful shutdown hook.
# INFO:tensorflow:Creating heartbeat manager for ['/job:tpu_worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 7 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.04093944, step = 41984
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.039431524, step = 43008 (23.751 sec)
# INFO:tensorflow:global_step/sec: 43.1146
# INFO:tensorflow:examples/sec: 44149.3
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.056689996, step = 44032 (22.127 sec)
# INFO:tensorflow:global_step/sec: 46.2772
# INFO:tensorflow:examples/sec: 47387.9
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.07731077, step = 45056 (39.860 sec)
# INFO:tensorflow:global_step/sec: 25.6896
# INFO:tensorflow:examples/sec: 26306.1
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.13897435, step = 46080 (22.149 sec)
# INFO:tensorflow:global_step/sec: 46.2337
# INFO:tensorflow:examples/sec: 47343.3
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.02831124, step = 47104 (22.138 sec)
# INFO:tensorflow:global_step/sec: 46.2555
# INFO:tensorflow:examples/sec: 47365.7
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.013631181, step = 48128 (22.136 sec)
# INFO:tensorflow:global_step/sec: 46.2607
# INFO:tensorflow:examples/sec: 47370.9
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.11632278, step = 49152 (22.128 sec)
# INFO:tensorflow:global_step/sec: 46.276
# INFO:tensorflow:examples/sec: 47386.6
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.053377558, step = 50176 (22.127 sec)
# INFO:tensorflow:global_step/sec: 46.2791
# INFO:tensorflow:examples/sec: 47389.8
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.076808706, step = 51200 (35.427 sec)
# INFO:tensorflow:global_step/sec: 28.9044
# INFO:tensorflow:examples/sec: 29598.1
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.17516252, step = 52224 (22.136 sec)
# INFO:tensorflow:global_step/sec: 46.2593
# INFO:tensorflow:examples/sec: 47369.5
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.089208566, step = 53248 (22.137 sec)
# INFO:tensorflow:global_step/sec: 46.2573
# INFO:tensorflow:examples/sec: 47367.5
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.07093637, step = 54272 (22.136 sec)
# INFO:tensorflow:global_step/sec: 46.2593
# INFO:tensorflow:examples/sec: 47369.5
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.03445144, step = 55296 (22.127 sec)
# INFO:tensorflow:global_step/sec: 46.2783
# INFO:tensorflow:examples/sec: 47389
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.035504095, step = 56320 (40.887 sec)
# INFO:tensorflow:global_step/sec: 25.0444
# INFO:tensorflow:examples/sec: 25645.5
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.034584645, step = 57344 (22.137 sec)
# INFO:tensorflow:global_step/sec: 46.26
# INFO:tensorflow:examples/sec: 47370.3
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.0885531, step = 58368 (22.141 sec)
# INFO:tensorflow:global_step/sec: 46.2473
# INFO:tensorflow:examples/sec: 47357.2
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.029206065, step = 59392 (22.137 sec)
# INFO:tensorflow:global_step/sec: 46.2568
# INFO:tensorflow:examples/sec: 47367
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.0977765, step = 60416 (41.309 sec)
# INFO:tensorflow:global_step/sec: 24.7877
# INFO:tensorflow:examples/sec: 25382.6
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.05507184, step = 61440 (22.151 sec)
# INFO:tensorflow:global_step/sec: 46.2335
# INFO:tensorflow:examples/sec: 47343.1
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.046042997, step = 62464 (22.139 sec)
# INFO:tensorflow:global_step/sec: 46.2527
# INFO:tensorflow:examples/sec: 47362.7
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.022956513, step = 63488 (22.138 sec)
# INFO:tensorflow:global_step/sec: 46.2553
# INFO:tensorflow:examples/sec: 47365.4
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.038613245, step = 64512 (22.140 sec)
# INFO:tensorflow:global_step/sec: 46.2499
# INFO:tensorflow:examples/sec: 47359.9
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:Saving checkpoints for 65536 into gs://gcolab/tpuestimator/2019-01-21-17-01-07/model.ckpt.
# INFO:tensorflow:loss = 0.029913457, step = 65536 (52.671 sec)
# INFO:tensorflow:global_step/sec: 19.4415
# INFO:tensorflow:examples/sec: 19908.1
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.06583932, step = 66560 (22.137 sec)
# INFO:tensorflow:global_step/sec: 46.258
# INFO:tensorflow:examples/sec: 47368.2
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.018531948, step = 67584 (22.156 sec)
# INFO:tensorflow:global_step/sec: 46.2128
# INFO:tensorflow:examples/sec: 47321.9
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.033575397, step = 68608 (22.147 sec)
# INFO:tensorflow:global_step/sec: 46.2424
# INFO:tensorflow:examples/sec: 47352.2
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.011916961, step = 69632 (22.139 sec)
# INFO:tensorflow:global_step/sec: 46.252
# INFO:tensorflow:examples/sec: 47362
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.05655975, step = 70656 (22.121 sec)
# INFO:tensorflow:global_step/sec: 46.2904
# INFO:tensorflow:examples/sec: 47401.3
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.05030904, step = 71680 (36.919 sec)
# INFO:tensorflow:global_step/sec: 27.7366
# INFO:tensorflow:examples/sec: 28402.3
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.019866465, step = 72704 (22.138 sec)
# INFO:tensorflow:global_step/sec: 46.2545
# INFO:tensorflow:examples/sec: 47364.6
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.15822138, step = 73728 (22.142 sec)
# INFO:tensorflow:global_step/sec: 46.247
# INFO:tensorflow:examples/sec: 47356.9
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.025836008, step = 74752 (22.143 sec)
# INFO:tensorflow:global_step/sec: 46.246
# INFO:tensorflow:examples/sec: 47355.9
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.062222183, step = 75776 (34.196 sec)
# INFO:tensorflow:global_step/sec: 29.9447
# INFO:tensorflow:examples/sec: 30663.4
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.03708345, step = 76800 (22.146 sec)
# INFO:tensorflow:global_step/sec: 46.2377
# INFO:tensorflow:examples/sec: 47347.4
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.025580425, step = 77824 (22.134 sec)
# INFO:tensorflow:global_step/sec: 46.2632
# INFO:tensorflow:examples/sec: 47373.5
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.017536022, step = 78848 (22.149 sec)
# INFO:tensorflow:global_step/sec: 46.2323
# INFO:tensorflow:examples/sec: 47341.8
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.049577605, step = 79872 (22.139 sec)
# INFO:tensorflow:global_step/sec: 46.2525
# INFO:tensorflow:examples/sec: 47362.6
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.060847986, step = 80896 (22.132 sec)
# INFO:tensorflow:global_step/sec: 46.2682
# INFO:tensorflow:examples/sec: 47378.6
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.046089545, step = 81920 (33.710 sec)
# INFO:tensorflow:global_step/sec: 30.377
# INFO:tensorflow:examples/sec: 31106
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.059458543, step = 82944 (22.153 sec)
# INFO:tensorflow:global_step/sec: 46.2231
# INFO:tensorflow:examples/sec: 47332.5
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.028817013, step = 83968 (22.138 sec)
# INFO:tensorflow:global_step/sec: 46.2561
# INFO:tensorflow:examples/sec: 47366.3
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.05377785, step = 84992 (22.138 sec)
# INFO:tensorflow:global_step/sec: 46.2566
# INFO:tensorflow:examples/sec: 47366.8
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.025816297, step = 86016 (22.127 sec)
# INFO:tensorflow:global_step/sec: 46.2775
# INFO:tensorflow:examples/sec: 47388.2
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.003410056, step = 87040 (39.107 sec)
# INFO:tensorflow:global_step/sec: 26.1845
# INFO:tensorflow:examples/sec: 26813
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.018628271, step = 88064 (22.129 sec)
# INFO:tensorflow:global_step/sec: 46.2732
# INFO:tensorflow:examples/sec: 47383.8
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.061437245, step = 89088 (22.148 sec)
# INFO:tensorflow:global_step/sec: 46.2347
# INFO:tensorflow:examples/sec: 47344.3
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:Saving checkpoints for 90112 into gs://gcolab/tpuestimator/2019-01-21-17-01-07/model.ckpt.
# INFO:tensorflow:loss = 0.069775045, step = 90112 (33.539 sec)
# INFO:tensorflow:global_step/sec: 30.5315
# INFO:tensorflow:examples/sec: 31264.2
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.022663143, step = 91136 (33.762 sec)
# INFO:tensorflow:global_step/sec: 30.3304
# INFO:tensorflow:examples/sec: 31058.3
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.032479953, step = 92160 (22.135 sec)
# INFO:tensorflow:global_step/sec: 46.2619
# INFO:tensorflow:examples/sec: 47372.2
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.01465276, step = 93184 (22.129 sec)
# INFO:tensorflow:global_step/sec: 46.2752
# INFO:tensorflow:examples/sec: 47385.8
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.041521244, step = 94208 (22.127 sec)
# INFO:tensorflow:global_step/sec: 46.2779
# INFO:tensorflow:examples/sec: 47388.6
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.005584446, step = 95232 (22.131 sec)
# INFO:tensorflow:global_step/sec: 46.2707
# INFO:tensorflow:examples/sec: 47381.2
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.048416376, step = 96256 (22.130 sec)
# INFO:tensorflow:global_step/sec: 46.2718
# INFO:tensorflow:examples/sec: 47382.4
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.047043514, step = 97280 (33.553 sec)
# INFO:tensorflow:global_step/sec: 30.519
# INFO:tensorflow:examples/sec: 31251.4
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.03295309, step = 98304 (22.129 sec)
# INFO:tensorflow:global_step/sec: 46.2748
# INFO:tensorflow:examples/sec: 47385.4
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.05702332, step = 99328 (22.147 sec)
# INFO:tensorflow:global_step/sec: 46.237
# INFO:tensorflow:examples/sec: 47346.7
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.042817224, step = 100352 (22.131 sec)
# INFO:tensorflow:global_step/sec: 46.2697
# INFO:tensorflow:examples/sec: 47380.1
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.019875426, step = 101376 (22.128 sec)
# INFO:tensorflow:global_step/sec: 46.2768
# INFO:tensorflow:examples/sec: 47387.5
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.036962487, step = 102400 (34.105 sec)
# INFO:tensorflow:global_step/sec: 30.0253
# INFO:tensorflow:examples/sec: 30745.9
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.011357386, step = 103424 (22.130 sec)
# INFO:tensorflow:global_step/sec: 46.2721
# INFO:tensorflow:examples/sec: 47382.7
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.011308415, step = 104448 (22.146 sec)
# INFO:tensorflow:global_step/sec: 46.2395
# INFO:tensorflow:examples/sec: 47349.2
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.06062569, step = 105472 (22.125 sec)
# INFO:tensorflow:global_step/sec: 46.2824
# INFO:tensorflow:examples/sec: 47393.2
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.013140942, step = 106496 (37.181 sec)
# INFO:tensorflow:global_step/sec: 27.5409
# INFO:tensorflow:examples/sec: 28201.9
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.027411448, step = 107520 (22.142 sec)
# INFO:tensorflow:global_step/sec: 46.2472
# INFO:tensorflow:examples/sec: 47357.1
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.020606285, step = 108544 (22.134 sec)
# INFO:tensorflow:global_step/sec: 46.2643
# INFO:tensorflow:examples/sec: 47374.7
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.051036753, step = 109568 (22.146 sec)
# INFO:tensorflow:global_step/sec: 46.2368
# INFO:tensorflow:examples/sec: 47346.5
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.048035722, step = 110592 (22.137 sec)
# INFO:tensorflow:global_step/sec: 46.2581
# INFO:tensorflow:examples/sec: 47368.3
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.07005835, step = 111616 (22.127 sec)
# INFO:tensorflow:global_step/sec: 46.2756
# INFO:tensorflow:examples/sec: 47386.3
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.0063228635, step = 112640 (33.281 sec)
# INFO:tensorflow:global_step/sec: 30.7693
# INFO:tensorflow:examples/sec: 31507.8
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.040148184, step = 113664 (22.131 sec)
# INFO:tensorflow:global_step/sec: 46.2668
# INFO:tensorflow:examples/sec: 47377.2
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:Saving checkpoints for 114688 into gs://gcolab/tpuestimator/2019-01-21-17-01-07/model.ckpt.
# INFO:tensorflow:loss = 0.023143474, step = 114688 (32.266 sec)
# INFO:tensorflow:global_step/sec: 31.7383
# INFO:tensorflow:examples/sec: 32500
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.011307561, step = 115712 (22.161 sec)
# INFO:tensorflow:global_step/sec: 46.2059
# INFO:tensorflow:examples/sec: 47314.8
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.063225895, step = 116736 (22.150 sec)
# INFO:tensorflow:global_step/sec: 46.232
# INFO:tensorflow:examples/sec: 47341.5
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.046424273, step = 117760 (37.084 sec)
# INFO:tensorflow:global_step/sec: 27.6123
# INFO:tensorflow:examples/sec: 28275
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.02072452, step = 118784 (22.142 sec)
# INFO:tensorflow:global_step/sec: 46.2463
# INFO:tensorflow:examples/sec: 47356.2
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.03677309, step = 119808 (22.140 sec)
# INFO:tensorflow:global_step/sec: 46.2507
# INFO:tensorflow:examples/sec: 47360.7
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.02173838, step = 120832 (22.137 sec)
# INFO:tensorflow:global_step/sec: 46.256
# INFO:tensorflow:examples/sec: 47366.1
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.02492781, step = 121856 (33.248 sec)
# INFO:tensorflow:global_step/sec: 30.7996
# INFO:tensorflow:examples/sec: 31538.7
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.019391663, step = 122880 (22.132 sec)
# INFO:tensorflow:global_step/sec: 46.2675
# INFO:tensorflow:examples/sec: 47377.9
# INFO:tensorflow:Saving checkpoints for 122880 into gs://gcolab/tpuestimator/2019-01-21-17-01-07/model.ckpt.
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Loss for final step: 0.019391663.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-21-18:03:01
# INFO:tensorflow:TPU job name worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://gcolab/tpuestimator/2019-01-21-17-01-07/model.ckpt-122880
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 7 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Enqueue next (1024) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1024) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1024/1024]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-01-21-18:03:21
# INFO:tensorflow:Saving dict for global step 122880: accuracy = 0.9877739, global_step = 122880, loss = 0.036972858
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 122880: gs://gcolab/tpuestimator/2019-01-21-17-01-07/model.ckpt-122880
# INFO:tensorflow:evaluation_loop marked as finished
# {'accuracy': 0.9877739, 'global_step': 122880, 'loss': 0.036972858}

# %%
predictions = list(estimator.predict(input_fn=predict_input_fn))
MC_probs = [p["probabilities"] for p in predictions]
MC_probs = np.array(MC_probs).reshape([params["nb_MC_samples"],10000,10])
predicted_probs = np.mean(MC_probs, axis=0)
predicted_std = np.std(MC_probs, axis=0)

from sklearn.metrics import accuracy_score
def one_hot(a, num_classes):
  return np.squeeze(np.eye(num_classes)[a.reshape(-1)])
ev = one_hot(eval_labels,10)
accuracy_score(y_true=ev,y_pred=np.round(predicted_probs,0))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:TPU job name worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://gcolab/tpuestimator/2019-01-21-17-01-07/model.ckpt-122880
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 9 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# ...
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:prediction_loop marked as finished
# 0.9898
